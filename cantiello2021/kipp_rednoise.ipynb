# %% [markdown]
# # Produce Kippenhahn Plots for Red Noise Project

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mkipp
import numpy as np
import mesa_reader as mr
import matplotlib.gridspec as gridspec

plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')


# set some global options
#plt.rcParams['figure.figsize'] = (6,10)
#plt.rcParams['figure.figsize'] = (8,6)
#plt.rcParams['legend.frameon'] = False
#plt.rcParams['legend.fontsize'] = 14
#plt.rcParams['legend.borderpad'] = 0.1
#plt.rcParams['legend.labelspacing'] = 0.1
#plt.rcParams['legend.handletextpad'] = 0.1
#plt.rcParams['font.family'] = 'stixgeneral'
#plt.rcParams['font.size'] = 16

# Finally set up the plotting to look a little nicer.
#plt.rcParams["savefig.dpi"] = 100
#plt.rcParams["figure.dpi"] = 100

# %%
####################################################
# Plt Options from Perna, Lazzati & Cantiello 2017 #
####################################################
plt.rcParams['figure.figsize'] = (6,5)
plt.rcParams['font.family'] = ['Times New Roman']
#plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['mathtext.rm'] = 'serif'
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['axes.titlepad'] = 20 
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['font.size'] = 16
plt.rcParams['legend.borderpad'] = 0.2
#plt.rc('legend', borderpad=0.2, markerscale=15., fancybox=False)
plt.rc('legend', borderpad=0.2, markerscale=1., fancybox=False)
plt.rcParams['legend.labelspacing'] = 0.5
plt.rcParams['legend.handletextpad'] = 0.5
plt.rcParams['legend.handlelength'] = 1
plt.rcParams["legend.framealpha"] = 1.0
####################################################

# %%
from Constants import Constants
c=Constants() 

# Define some colors
BLACK      = (0.00,0.00,0.00)
ORANGE     = (0.90,0.60,0.00)
SKY_BLUE   = (0.35,0.70,0.90)
BLUE_GREEN = (0.00,0.60,0.50)
YELLOW     = (0.95,0.90,0.25)
BLUE       = (0.00,0.45,0.70)
VERMILLION = (0.80,0.40,0.00)
RED_PURPLE = (0.80,0.60,0.70)
# Out:
# Constants defined...

# %%
DIR = '/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0/'
DIR = '/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/'

FIGURES='./figures/'
mod='20'
h=mr.MesaData(DIR+mod+'/LOGS/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age

myr=1e6
max_age=max(star_age)/myr
print(max_age)
# Out:
# 8.210982136444827

# %%
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[DIR+mod+'/LOGS/'],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(0,max_age)
#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.1,0.88),xycoords='axes fraction',fontsize=18)


axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"m/M$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_mass_"+mod+".pdf")
# Out:
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS/ ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS/']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones

# %%
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[DIR+mod+'/LOGS/'],xaxis="star_age",yaxis="radius",yresolution=1000,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(0,4.7)

axis.set_ylim(0,10.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_"+mod+".pdf")
# Out:
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS/ ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS/']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones

# %%
#plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')
#plt.rcParams['figure.figsize'] = (6,8)
plt.rcParams['figure.figsize'] = (6,5)



fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[DIR+mod+'/LOGS/'],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],levels=[10,100,1000],decorate_plot = False,show_over = True), axis = axis)
axis.set_xlim(0,5)
axis.set_ylim(0.96,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+'$\,$M$_\odot$',(0.05,0.05),xycoords='axes fraction',fontsize=20)


#axis.annotate('HeII',(300,0.9912),fontsize=15)
#axis.annotate('HeI',(300,0.99774),fontsize=15)
#axis.annotate('H',(302,0.99918),fontsize=15)


r_hp_1 = h.r_hp_1
r_hp_2 = h.r_hp_2
r_hp_3 = h.r_hp_3
r_hp_5 = h.r_hp_5
r_hp_7 = h.r_hp_7
r_hp_10 = h.r_hp_10

rsun=6.9598e10
radius = 10**h.log_R
radius=radius*rsun
 

axis.plot(star_age/myr,r_hp_1/radius,c=BLACK,ls=':')
axis.plot(star_age/myr,r_hp_3/radius,c=BLACK,ls=':')
axis.plot(star_age/myr,r_hp_5/radius,c=BLACK,ls=':')
axis.plot(star_age/myr,r_hp_7/radius,c=BLACK,ls=':')
#axis.plot(star_age/myr,r_hp_10/radius,c=BLACK,ls=':')

aa = np.max(np.where(star_age/myr < 4.2))

delta =0.0025

axis.annotate(r'  H$_{\rm P}$',(4,r_hp_1[aa]/radius[aa] - delta))#,fontsize=5)
axis.annotate(r'3H$_{\rm P}$',(4,r_hp_3[aa]/radius[aa]- delta))#,fontsize=5)
axis.annotate(r'5H$_{\rm P}$',(4,r_hp_5[aa]/radius[aa]- delta))#,fontsize=5)
axis.annotate(r'7H$_{\rm P}$',(4,r_hp_7[aa]/radius[aa]- delta))#,fontsize=5)

axis.annotate(r'FeCZ',(2,0.981))#,fontsize=5)
#axis.annotate(r'HeCZ',(2.2,0.998),fontsize=7)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/$R_*$")
#bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
#bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig(FIGURES+"kipp_radius_norm_"+mod+".pdf")
# Out:
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS/ ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS/']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones

# %% [markdown]
# ## Stack Plot (2 Panels)

# %%
#plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')


gs1 = gridspec.GridSpec(2, 2,height_ratios=[1,1],width_ratios=[25,1])
# No space between plots, e.g.: gs1.update(left=0.1, right=0.9, wspace=0.00,hspace=0.00)
gs1.update(wspace=0.05,hspace=0.05)
# Assign axis and remove xticks from top plot
#ax1 = plt.subplot(gs1[0,0])
ax1 = plt.subplot(gs1[0,0])
ax2 = plt.subplot(gs1[1,0])
ax3 = plt.subplot(gs1[:,1])

kipp_plot1 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[DIR+mod+'/LOGS/'],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = ax1)
ax1.set_xlim(0,max_age)
ax1.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.55,0.82),xycoords='axes fraction',fontsize=18)
#bar1 = plt.colorbar(kipp_plot1.contour_plot,pad=0.05)
#bar1.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

ax1.set_ylabel(r"m/M$_\odot$")


kipp_plot2 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[DIR+mod+'/LOGS/'],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = ax2)
ax2.set_xlim(0,max_age)

#bar2 = plt.colorbar(kipp_plot2.contour_plot,pad=0.05)
#bar2.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

#ax2.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)
ax2.set_ylabel(r"r/R$_\odot$")

ax2.set_xlabel("Age (Myr)")

bar2 = plt.colorbar(kipp_plot2.contour_plot,cax=ax3)
bar2.set_label(r"$\log$ ($\epsilon_{\rm nuc}$/erg/g/s)")

ax2.set_ylim(0,8.0)
ax1.set_xlim(0,4.7)
ax2.set_xlim(0,4.7)

ax1.set_xticks([])

plt.savefig("kipp_2stack.pdf")
# Out:
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0/20/LOGS/ ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0/20/LOGS/']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/astro/python/mkipp-master/mkipp.py:298: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig(kipp_args.save_filename)
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0/20/LOGS/ ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0/20/LOGS/']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/astro/python/mkipp-master/mkipp.py:298: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig(kipp_args.save_filename)
# ...

# %% [markdown]
# ## Full Panel Stack Plot

# %%
plt.rcParams['figure.figsize'] = (12,9)
#plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')


outer = gridspec.GridSpec(1, 2) 
#make nested gridspecs
gs1 = gridspec.GridSpecFromSubplotSpec(1, 1, subplot_spec = outer[0])

#  OLD KIPP PLOTS 
gs1 = gridspec.GridSpec(2, 2,height_ratios=[1,1],width_ratios=[25,1],subplot_spec = outer[0])
gs1.update(wspace=0.05,hspace=0.05)

ax1 = plt.subplot(gs1[:,1])
ax2 = plt.subplot(gs1[0,0])
ax3 = plt.subplot(gs1[1,0])



# RADIAL NORMALIZED

gs2 = gridspec.GridSpecFromSubplotSpec(1, 1, subplot_spec = outer[1], hspace = .05)

ax4 = plt.subplot(gs2[0])

# No space between plots, e.g.: gs1.update(left=0.1, right=0.9, wspace=0.00,hspace=0.00)
gs1.update(wspace=0.15,hspace=0.05)
# Assign axis and remove xticks from top plot
#ax1 = plt.subplot(gs1[0,0])
#ax4 = plt.subplot(gs1[0,0])
#ax2 = plt.subplot(gs1[1,0])
#ax3 = plt.subplot(gs1[:,1])
#ax1 = plt.subplot(gs1[:,2])

# 
ax4 = plt.subplot(gs1[:,0])
ax2 = plt.subplot(gs1[1,1])
ax3 = plt.subplot(gs1[:,2])
ax1 = plt.subplot(gs1[0,1])

kipp_plot1 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = ax1)
ax1.set_xlim(0,max_age)
ax1.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.55,0.82),xycoords='axes fraction',fontsize=18)
#bar1 = plt.colorbar(kipp_plot1.contour_plot,pad=0.05)
#bar1.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

ax1.set_ylabel(r"m/M$_\odot$")


kipp_plot2 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = ax2)
ax2.set_xlim(0,max_age)

#bar2 = plt.colorbar(kipp_plot2.contour_plot,pad=0.05)
#bar2.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

#ax2.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)
ax2.set_ylabel(r"r/R$_\odot$")

ax2.set_xlabel("Age (Myr)")

bar2 = plt.colorbar(kipp_plot2.contour_plot,cax=ax3)
bar2.set_label(r"$\log$ ($\epsilon_{\rm nuc}$/erg/g/s)")

ax1.set_xticks([])


# RIGHT NORMALIZED PLOT


kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = True), axis = ax4)
ax4.set_xlim(0,max_age)
ax4.set_ylim(0.98,1.0)

ax4.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.05),xycoords='axes fraction')#,fontsize=5)


ax4.annotate('HeII',(300,0.9912),fontsize=15)
ax4.annotate('HeI',(300,0.99774),fontsize=15)
ax4.annotate('HI',(302,0.99918),fontsize=15)

#ax4.yaxis.tick_right()
#ax4.yaxis.set_label_position("right")


ax4.set_xlabel("Age (Myr)")
ax4.set_ylabel(r"r/R$_*$")



plt.savefig("kipp_panel.pdf")

# %% [markdown]
# ## Stack Plot (3 Panels)

# %%
plt.rcParams['figure.figsize'] = (6,12)
plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')



gs1 = gridspec.GridSpec(3, 1,height_ratios=[1,1,1])
# No space between plots, e.g.: gs1.update(left=0.1, right=0.9, wspace=0.00,hspace=0.00)
gs1.update(wspace=0.00,hspace=0.05)
# Assign axis and remove xticks from top plot
#ax1 = plt.subplot(gs1[0,0])
ax1 = plt.subplot(gs1[0,0])
ax2 = plt.subplot(gs1[1,0])
ax3 = plt.subplot(gs1[2,0])


kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = ax1)
ax1.set_xlim(0,max_age)
ax1.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.64,0.82),xycoords='axes fraction',fontsize=18)


ax1.set_ylabel(r"m/M$_\odot$")


kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = ax2)
ax2.set_xlim(0,max_age)


#ax2.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)
ax2.set_ylabel(r"r/R$_\odot$")



ax1.set_xticks([])
ax2.set_xticks([])

kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = True), axis = ax3)
ax3.set_xlim(0,max_age)
ax3.set_ylim(0.98,1.0)

#ax3.annotate(r'M$_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.05),xycoords='axes fraction')#,fontsize=5)

ax3.annotate('HeII',(300,0.9912))#,fontsize=5)
ax3.annotate('HeI',(300,0.99774))#,fontsize=5)
ax3.annotate('HI',(302,0.99918))#,fontsize=5)

ax3.set_xlabel("Age (Myr)")



plt.savefig("kipp_3stack.pdf")

# %%
    import mesa_reader as mr
    import numpy as np
    import matplotlib.pyplot as plt
    ​
    data = mr.MesaData(file_name='./LOGS/history.data')
    index = mr.MesaProfileIndex(file_name='./LOGS/profiles.index')
    ​
    last_model = index.model_numbers[-1]
    last_model_name = index.profile_with_model_number(last_model)
    ​
    prof = mr.MesaData(file_name='./LOGS/profile' + str(last_model_name) + '.data')
    ​
    Rsun = 7e10
    ​
    opacity = prof.data('opacity')
    R = Rsun * 10**prof.data('logR')
    D = 10**prof.data('logRho')
    T = 10**prof.data('logT')
    N2 = prof.data('brunt_N2')
    N2_thermal = prof.data('brunt_N2_composition_term')
    ​
    R_with_zero = np.array(list(R) + [0])
    dR = np.diff(R_with_zero)
    ​
    sel = ((N2 < 0) & (R < 0.2 * R[0]))
    N2_conv_avg = -np.sum(N2[sel] * dR[sel]) / np.sum(dR[sel])
    N_conv_avg = N2_conv_avg**0.5
    ​
    l_grid = 1 + np.arange(20)
    f_grid = N_conv_avg * 10**np.linspace(-2,2,num=20,endpoint=True)
    ​
    def make_plot(l,f):
    ​
        k_perp = (l * (l + 1))**0.5 / R
        k_r = k_perp * (N2**0.5 / f)
    ​
        vA_crit_radial = f / k_r / 2 # Correction of 2 due to Fuller+2015
        B_crit_wave_radial = vA_crit_radial * (4 * np.pi * D)**0.5
        vA_crit_toroidal = f / k_perp / 2 # Correction of 2 due to Fuller+2015
        B_crit_wave_toroidal = vA_crit_toroidal * (4 * np.pi * D)**0.5
    ​
    ​
        plt.plot(R / R[0], B_crit_wave_radial, label='$B_{\mathrm{crit,wave,radial}} / \mathrm{G}$', linestyle='--')
        plt.plot(R / R[0], B_crit_wave_toroidal, label='$B_{\mathrm{crit,wave,toroidal}} / \mathrm{G}$')
        plt.plot(R / R[0], vA_crit_radial, label='$v_{A,\mathrm{crit,radial}} / \mathrm{G}$', linestyle='--')
        plt.plot(R / R[0], N2**0.5, label='$N / \mathrm{s^{-1}}$')
        plt.plot(R / R[0], R*k_r, label='$r k_r$')
        plt.axhline(f, label='$\omega$',linestyle='-.')
        plt.title('l = ' + str(l) + ' ' + 'f = ' + str(round(f / N_conv_avg,2)) + ' f_conv')
        plt.legend()
        plt.xlabel('r / R')
        plt.yscale('log')
        plt.savefig(str(l) + '_' + str(round(f / N_conv_avg,2)) + '.pdf')
        plt.close()
    ​
    ​
    def make_composite_plot(ls,fs,ftitles):
    ​
        plt.figure(figsize=(5,4))
    ​
        for l,f,ftitle in zip(*(ls,fs,ftitles)):
    ​
            k_perp = (l * (l + 1))**0.5 / R
            k_r = k_perp * (N2**0.5 / f)
    ​
            vA_crit_radial = f / k_r / 2 # Correction of 2 due to Fuller+2015
            B_crit_wave_radial = vA_crit_radial * (4 * np.pi * D)**0.5
    ​
            plt.plot(1-R / R[0], B_crit_wave_radial, label='$\ell = ' + str(l) + ', \\nu =  ' + ftitle + '$')
        plt.legend(loc='center right')
        plt.xlim([1e-5,1e-2])
        plt.ylim([1e-2,1e5])
        plt.xscale('log')
        plt.xlabel('$1 - r / R_\star$')
        plt.yscale('log')
        plt.ylabel('$B_{r,\mathrm{crit}} / \mathrm{G}$')
        plt.tight_layout()
        plt.savefig('composite.pdf')
        plt.close()
    ​
    make_composite_plot([1,2,3,1,2,3], 3*[N_conv_avg] + 3*[2*np.pi*5/(24*3600)], 3*['\\nu_\mathrm{char,MLT}'] + 3*['\\nu_\mathrm{char,Obs}'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-199-f98b23bc8636> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 data = mr.MesaData(file_name='./LOGS/history.data')
#       6 index = mr.MesaProfileIndex(file_name='./LOGS/profiles.index')
#       7
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/mesa_reader-0.3.0-py3.7.egg/mesa_reader/__init__.py in __init__(self, file_name, file_type)
#     119         self.header_data = None
#     120         self.header_names = None
# --> 121         self.read_data()
#     122
#     123     def read_data(self):
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/mesa_reader-0.3.0-py3.7.egg/mesa_reader/__init__.py in read_data(self)
#     151             self.read_model_data()
#     152         elif self.file_type == 'log':
# --> 153             self.read_log_data()
# ...
