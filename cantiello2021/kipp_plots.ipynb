# %% [markdown]
# # Produce Kippenhahn Plots for Cantiello & Braithwaite 2019

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mkipp
import numpy as np
import mesa_reader as mr
import matplotlib.gridspec as gridspec

plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')


# set some global options
#plt.rcParams['figure.figsize'] = (6,10)
#plt.rcParams['figure.figsize'] = (8,6)
#plt.rcParams['legend.frameon'] = False
#plt.rcParams['legend.fontsize'] = 14
#plt.rcParams['legend.borderpad'] = 0.1
#plt.rcParams['legend.labelspacing'] = 0.1
#plt.rcParams['legend.handletextpad'] = 0.1
#plt.rcParams['font.family'] = 'stixgeneral'
#plt.rcParams['font.size'] = 16

# Finally set up the plotting to look a little nicer.
#plt.rcParams["savefig.dpi"] = 100
#plt.rcParams["figure.dpi"] = 100

# %%
mod='2.4'
directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age

myr=1e6
max_age=max(star_age)/myr
print(max_age)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-e4d87b4b6042> in <module>
#       1 mod='2.4'
#       2 directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
# ----> 3 h=mr.MesaData(directory+'/history.data')
#       4 model = h.model_number
#       5 logl = h.log_L
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/mesa_reader-0.3.0-py3.7.egg/mesa_reader/__init__.py in __init__(self, file_name, file_type)
#     119         self.header_data = None
#     120         self.header_names = None
# --> 121         self.read_data()
#     122
#     123     def read_data(self):
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/mesa_reader-0.3.0-py3.7.egg/mesa_reader/__init__.py in read_data(self)
#     151             self.read_model_data()
#     152         elif self.file_type == 'log':
# --> 153             self.read_log_data()
#     154         else:
#     155             raise UnknownFileTypeError("Unknown file type {}".format(
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/mesa_reader-0.3.0-py3.7.egg/mesa_reader/__init__.py in read_log_data(self)
#     169         """
#     170         self.bulk_data = np.genfromtxt(self.file_name,
# --> 171             skip_header=MesaData.bulk_names_line - 1, names=True, dtype=None)
#     172         self.bulk_names = self.bulk_data.dtype.names
#     173         header_data = []
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1770             fname = os_fspath(fname)
#    1771         if isinstance(fname, basestring):
# -> 1772             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1773             fid_ctx = contextlib.closing(fid)
#    1774         else:
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/anaconda/envs/matplotlib_build/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: /Users/mcantiello/astro/work/astars/2.4/LOGS/history.data not found.

# %%
mod='2.4'


fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(0,max_age)
#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.7,0.88),xycoords='axes fraction',fontsize=18)


axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"m/M$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_mass.pdf")
# Out:
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(0,max_age)

#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius.pdf")
# Out:
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')
#plt.rcParams['figure.figsize'] = (6,8)
plt.rcParams['figure.figsize'] = (6,9)




fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = True), axis = axis)
axis.set_xlim(0,max_age)
axis.set_ylim(0.98,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.05),xycoords='axes fraction')#,fontsize=5)


axis.annotate('HeII',(300,0.9912),fontsize=15)
axis.annotate('HeI',(300,0.99774),fontsize=15)
axis.annotate('H',(302,0.99918),fontsize=15)





axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_*$")
#bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
#bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_norm.pdf")
# Out:
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = True), axis = axis)
axis.set_xlim(0,max_age)
axis.set_ylim(0.98,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.05),xycoords='axes fraction')#,fontsize=5)

axis.annotate('HeII',(300,0.9912))#,fontsize=5)
axis.annotate('HeI',(300,0.99774))#,fontsize=5)
axis.annotate('H',(302,0.99918))#,fontsize=5)





axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_*$")
#bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
#bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_norm.pdf")
# Out:
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = axis)

plt.set_cmap('Pastel1')


#tau10_radius
rsun=6.9598e10
myr=1e6
radius=rsun*10**h.log_R
hp1=h.r_hp_1/radius
hp2=h.r_hp_2/radius
hp4=h.r_hp_4/radius
hp6=h.r_hp_6/radius
hp8=h.r_hp_8/radius
hp10=h.r_hp_10/radius



alpha=0.3
ls=['-','--','-.',':']
dashList = [(1,1),(2,5),(5,2),(3,3,2,2),(5,2,20,2)]

color='black'
#axis.plot(h.star_age/myr,hp1,c=color,alpha=alpha,ls=ls[1],dashes=dashList[0],label='1 H$_P$')
#axis.plot(h.star_age/myr,hp2,c=color,alpha=alpha,ls=ls[1],dashes=dashList[1],label='2 H$_P$')
#axis.plot(h.star_age/myr,hp4,c=color,alpha=alpha,ls=ls[1],dashes=dashList[2],label='4 H$_P$')
#axis.plot(h.star_age/myr,hp6,c=color,alpha=alpha,ls=ls[1],dashes=dashList[3],label='6 H$_P$')
#axis.plot(h.star_age/myr,hp8,c=color,alpha=alpha,ls=ls[1],dashes=dashList[4],label='8 H$_P$')
##axis.plot(h.star_age/myr,hp10,c=color,alpha=alpha,label='1H$_P$')
#legend = axis.legend(loc='lower left')#,frameon = True)




axis.set_xlim(0,max_age)
axis.set_ylim(0.98,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.1),xycoords='axes fraction')#,fontsize=5)

axis.annotate('HeII',(300,0.9912))#,fontsize=5)
axis.annotate('HeI',(300,0.99774))#,fontsize=5)
axis.annotate('H',(302,0.99918))#,fontsize=5)




axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_*$")
#bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
#bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_norm_hp.pdf")
# Out:
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Stack Plot (2 Panels)

# %%
#plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')


gs1 = gridspec.GridSpec(2, 2,height_ratios=[1,1],width_ratios=[25,1])
# No space between plots, e.g.: gs1.update(left=0.1, right=0.9, wspace=0.00,hspace=0.00)
gs1.update(wspace=0.05,hspace=0.05)
# Assign axis and remove xticks from top plot
#ax1 = plt.subplot(gs1[0,0])
ax1 = plt.subplot(gs1[0,0])
ax2 = plt.subplot(gs1[1,0])
ax3 = plt.subplot(gs1[:,1])

kipp_plot1 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = ax1)
ax1.set_xlim(0,max_age)
ax1.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.55,0.82),xycoords='axes fraction',fontsize=18)
#bar1 = plt.colorbar(kipp_plot1.contour_plot,pad=0.05)
#bar1.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

ax1.set_ylabel(r"m/M$_\odot$")


kipp_plot2 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = ax2)
ax2.set_xlim(0,max_age)

#bar2 = plt.colorbar(kipp_plot2.contour_plot,pad=0.05)
#bar2.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

#ax2.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)
ax2.set_ylabel(r"r/R$_\odot$")

ax2.set_xlabel("Age (Myr)")

bar2 = plt.colorbar(kipp_plot2.contour_plot,cax=ax3)
bar2.set_label(r"$\log$ ($\epsilon_{\rm nuc}$/erg/g/s)")

ax1.set_xticks([])

plt.savefig("kipp_2stack.pdf")
# Out:
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Full Panel Stack Plot

# %%
plt.rcParams['figure.figsize'] = (12,9)
#plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')


outer = gridspec.GridSpec(1, 2) 
#make nested gridspecs
gs1 = gridspec.GridSpecFromSubplotSpec(1, 1, subplot_spec = outer[0])

#  OLD KIPP PLOTS 
gs1 = gridspec.GridSpec(2, 2,height_ratios=[1,1],width_ratios=[25,1],subplot_spec = outer[0])
gs1.update(wspace=0.05,hspace=0.05)

ax1 = plt.subplot(gs1[:,1])
ax2 = plt.subplot(gs1[0,0])
ax3 = plt.subplot(gs1[1,0])



# RADIAL NORMALIZED

gs2 = gridspec.GridSpecFromSubplotSpec(1, 1, subplot_spec = outer[1], hspace = .05)

ax4 = plt.subplot(gs2[0])

# No space between plots, e.g.: gs1.update(left=0.1, right=0.9, wspace=0.00,hspace=0.00)
gs1.update(wspace=0.15,hspace=0.05)
# Assign axis and remove xticks from top plot
#ax1 = plt.subplot(gs1[0,0])
#ax4 = plt.subplot(gs1[0,0])
#ax2 = plt.subplot(gs1[1,0])
#ax3 = plt.subplot(gs1[:,1])
#ax1 = plt.subplot(gs1[:,2])

# 
ax4 = plt.subplot(gs1[:,0])
ax2 = plt.subplot(gs1[1,1])
ax3 = plt.subplot(gs1[:,2])
ax1 = plt.subplot(gs1[0,1])

kipp_plot1 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = ax1)
ax1.set_xlim(0,max_age)
ax1.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.55,0.82),xycoords='axes fraction',fontsize=18)
#bar1 = plt.colorbar(kipp_plot1.contour_plot,pad=0.05)
#bar1.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

ax1.set_ylabel(r"m/M$_\odot$")


kipp_plot2 = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = ax2)
ax2.set_xlim(0,max_age)

#bar2 = plt.colorbar(kipp_plot2.contour_plot,pad=0.05)
#bar2.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")

#ax2.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)
ax2.set_ylabel(r"r/R$_\odot$")

ax2.set_xlabel("Age (Myr)")

bar2 = plt.colorbar(kipp_plot2.contour_plot,cax=ax3)
bar2.set_label(r"$\log$ ($\epsilon_{\rm nuc}$/erg/g/s)")

ax1.set_xticks([])


# RIGHT NORMALIZED PLOT


kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = True), axis = ax4)
ax4.set_xlim(0,max_age)
ax4.set_ylim(0.98,1.0)

ax4.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.05),xycoords='axes fraction')#,fontsize=5)


ax4.annotate('HeII',(300,0.9912),fontsize=15)
ax4.annotate('HeI',(300,0.99774),fontsize=15)
ax4.annotate('HI',(302,0.99918),fontsize=15)

#ax4.yaxis.tick_right()
#ax4.yaxis.set_label_position("right")


ax4.set_xlabel("Age (Myr)")
ax4.set_ylabel(r"r/R$_*$")



plt.savefig("kipp_panel.pdf")

# %% [markdown]
# ## Stack Plot (3 Panels)

# %%
plt.rcParams['figure.figsize'] = (6,12)
plt.style.use('/Users/mcantiello/.matplotlib/mesa.mplstyle')



gs1 = gridspec.GridSpec(3, 1,height_ratios=[1,1,1])
# No space between plots, e.g.: gs1.update(left=0.1, right=0.9, wspace=0.00,hspace=0.00)
gs1.update(wspace=0.00,hspace=0.05)
# Assign axis and remove xticks from top plot
#ax1 = plt.subplot(gs1[0,0])
ax1 = plt.subplot(gs1[0,0])
ax2 = plt.subplot(gs1[1,0])
ax3 = plt.subplot(gs1[2,0])


kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yresolution=100,core_masses=[],decorate_plot = False), axis = ax1)
ax1.set_xlim(0,max_age)
ax1.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.64,0.82),xycoords='axes fraction',fontsize=18)


ax1.set_ylabel(r"m/M$_\odot$")


kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False,show_over = False), axis = ax2)
ax2.set_xlim(0,max_age)


#ax2.annotate(r'M$_{\rm ini}$ = '+mod+' $M_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)
ax2.set_ylabel(r"r/R$_\odot$")



ax1.set_xticks([])
ax2.set_xticks([])

kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yaxis_normalize=True,yresolution=100,core_masses=[],decorate_plot = False,show_over = True), axis = ax3)
ax3.set_xlim(0,max_age)
ax3.set_ylim(0.98,1.0)

#ax3.annotate(r'M$_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.05),xycoords='axes fraction')#,fontsize=5)

ax3.annotate('HeII',(300,0.9912))#,fontsize=5)
ax3.annotate('HeI',(300,0.99774))#,fontsize=5)
ax3.annotate('HI',(302,0.99918))#,fontsize=5)

ax3.set_xlabel("Age (Myr)")



plt.savefig("kipp_3stack.pdf")

# %% [markdown]
# ## Plots for Daniel

# %%
def find_zams(logl,loglh,model):
    zams=1
    while (loglh[zams] < 1.0*logl[zams]): 
     zams=zams+1
    return zams; 

mod = '0.4'

directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age

myr=1e6

zams=find_zams(logl,loglh,model)
zams_age = star_age[zams]/myr

max_age=max(star_age)/myr
print(max_age)
print(zams_age)

fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(zams_age,max_age)

#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_04.pdf")
# Out:
# 197447.378614
# 0.18
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
def find_zams(logl,loglh,model):
    zams=1
    while (loglh[zams] < 1.0*logl[zams]): 
     zams=zams+1
    return zams; 

mod = '0.7'

directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age


myr=1e6

zams=find_zams(logl,loglh,model)
zams_age = star_age[zams]/myr

max_age=max(star_age)/myr
print(max_age)
print(zams_age)

fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(zams_age,max_age)

#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_07.pdf")
# Out:
# 39322.0422385
# 0.22
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
def find_zams(logl,loglh,model):
    zams=1
    while (loglh[zams] < 1.0*logl[zams]): 
     zams=zams+1
    return zams; 

mod = '1.75'

directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age

myr=1e6

zams=find_zams(logl,loglh,model)
zams_age = star_age[zams]/myr

max_age=max(star_age)/myr
print(max_age)
print(zams_age)

fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(zams_age,max_age)

#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_175.pdf")
# Out:
# 1591.29048596
# 0.0222150547401
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
def find_zams(logl,loglh,model):
    zams=1
    while (loglh[zams] < 1.0*logl[zams]): 
     zams=zams+1
    return zams; 

mod = '4.0'

directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age

myr=1e6

zams=find_zams(logl,loglh,model)
zams_age = star_age[zams]/myr

max_age=max(star_age)/myr
print(max_age)
print(zams_age)

fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(zams_age,max_age)

#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_4.pdf")
# Out:
# 169.595120231
# 0.006875
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
def find_zams(logl,loglh,model):
    zams=1
    while (loglh[zams] < 1.0*logl[zams]): 
     zams=zams+1
    return zams; 

mod = '1.0'

directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age

myr=1e6

zams=find_zams(logl,loglh,model)
zams_age = star_age[zams]/myr

max_age=max(star_age)/myr
print(max_age)
print(zams_age)

fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
axis.set_xlim(zams_age,max_age)

#axis.set_ylim(0,1.0)

axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius_1.pdf")
# Out:
# 8895.28937891
# 0.181742641181
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
mod = '1.0'
directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
h=mr.MesaData(directory+'/history.data')
model = h.model_number 
logl = h.log_L
loglh=h.log_LH 
center_h1 = h.center_h1 
logt= h.log_Teff 
log_dt = h.log_dt
star_age = h.star_age
myr=1e6

zams=find_zams(logl,loglh,model)
zams_age = star_age[zams]/myr

# %%
c12=h.center_c12
pp=h.pp
cno=h.cno
n14=h.center_n14
h1=h.center_h1

# %%
fig = plt.figure()
axis = plt.gca()
plt.plot(star_age/myr,c12)
plt.plot(star_age/myr,h1)
plt.plot(star_age/myr,n14)
#plt.plot(star_age,pp)
#plt.plot(star_age,cno)
axis.set_xlim(zams_age,max_age)
# Out:
# (0.1817426411809783, 8895.2893789108275)
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig = plt.figure()
axis = plt.gca()

plt.plot(star_age/myr,pp)
plt.plot(star_age/myr,cno,ls='--')
axis.set_xlim(zams_age,max_age)
#axis.set_ylim(0,5)
# Out:
# (0.1817426411809783, 8895.2893789108275)
# /Users/mcantiello/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#mod = '1.0'
#directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
directory = '/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS'

#directory='/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.002/9.0/LOGS'
h=mr.MesaData(directory+'/history.data')
star_age=h.star_age
max_age = max(star_age)
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
#axis.set_xlim(0,max_age)

axis.set_ylim(0,8)

#axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius.pdf")
# Out:
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.02_CORE_F0_NO_OVER/20/LOGS']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones

# %%
#mod = '1.0'
#directory='/Users/mcantiello/astro/work/astars/'+mod+'/LOGS'
directory='/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.002/9.0/LOGS'
h=mr.MesaData(directory+'/history.data')
star_age=h.star_age
max_age = max(star_age)
fig = plt.figure()
axis = plt.gca()
kipp_plot = mkipp.kipp_plot(mkipp.Kipp_Args(logs_dirs=[directory],xaxis="star_age",yaxis="radius",yresolution=100,core_masses=[],decorate_plot = False), axis = axis)
#axis.set_xlim(0,max_age)

axis.set_ylim(0,8)

#axis.annotate(r'$M_{\rm ini}$ = '+mod+' M$_\odot$',(0.05,0.85),xycoords='axes fraction')#,fontsize=5)

axis.set_xlabel("Age (Myr)")
axis.set_ylabel(r"r/R$_\odot$")
bar = plt.colorbar(kipp_plot.contour_plot,pad=0.05)
bar.set_label(r"$\log$ [$\epsilon_{\rm nuc}$/erg/g/s]")
plt.savefig("kipp_radius2.pdf")
# Out:
# /Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.002/9.0/LOGS ['/Users/mcantiello/Dropbox (Personal)/work/red_noise/15140/Z0.002/9.0/LOGS']
# Reading profile data
# Reading history data
# Constructing mixing regions
# there are 10 mixing zones
